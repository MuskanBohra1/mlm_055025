# %% [markdown]
# # **Imports and Exports Data Analysis**

# %% [markdown]
# Name : Muskan Bohra
#
# Roll No : 055025
#
# Section : K
#
# Individual Project

# %% [markdown]
# # **General Descriptions of Data**

# %% [markdown]
# - **Data Source**: The dataset originates from a comprehensive record of import and export transactions, capturing various attributes associated with each transaction.
#
# - **Data Type**: The dataset is organized in a tabular format (CSV) and includes both categorical variables (e.g., Country, Product, Shipping_Method) and numerical variables (e.g., Quantity, Value, Weight).
#
# - **Data Structure**: The dataset comprises multiple columns such as Transaction_ID, Country, Product, Import_Export (indicating whether the transaction is an import or export), Quantity, Value, Date, Category, Port, Customs_Code, Weight, Shipping_Method, Supplier, Customer, Invoice_Number, and Payment_Terms.

# %% [markdown]
# ## Data Description

# %% [markdown]
# ### Dataset Overview
#
# The dataset, sourced from Kaggle ([Imports-Exports Dataset](https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000)), contains information on international trade transactions. It consists of **15,000 rows** and **16 columns**, where each row represents a unique transaction. The dataset provides a comprehensive view of imports and exports conducted between 2019 and 2024, with a majority of transactions occurring in 2021 and 2022.
#
# ### Data Features
#
# **Columns**:
# 1. **Transaction_ID**: A unique identifier assigned to each transaction.
# 2. **Country**: The country participating in the transaction, either as the origin (export) or destination (import).
# 3. **Product**: The type of product traded.
# 4. **Import_Export**: Specifies whether the transaction is an import or export.
# 5. **Quantity**: The quantity of the traded product.
# 6. **Value**: The total value of the transaction in USD.
# 7. **Date**: The date of the transaction, formatted as DD-MM-YYYY.
# 8. **Category**: Product category, such as Machinery, Clothing, Electronics, Furniture, or Toys.
# 9. **Port**: The port where the transaction was executed.
# 10. **Customs_Code**: A unique customs identifier for the transaction.
# 11. **Weight**: The weight of the traded goods in kilograms.
# 12. **Shipping_Method**: The transportation method used for the transaction (e.g., Air or Sea).
# 13. **Supplier**: The company supplying the goods.
# 14. **Customer**: The recipient of the traded goods.
# 15. **Invoice_Number**: A unique identifier for the transaction's invoice.
# 16. **Payment_Terms**: The payment conditions agreed upon, such as Cash on Delivery, Prepaid, or Net terms (e.g., Net 30, Net 60).
#
# ### Data Characteristics
#
# - **Time Frame**: 2019–2024
# - **Focus Period**: 2021 and 2022 comprise the bulk of the records.
# - **Geographic Scope**: Includes transactions from multiple countries across various product categories.
#
# ### Data Dimensions
#
# - **Number of Variables**: 16
# - **Number of Observations**: 15,000
#
# ### Variable Classification
#
# 1. **Index**:
#    - `Transaction_ID`: Unique transaction identifier.
#
# 2. **Categorical Variables**:
#    - **Nominal**: `Country`, `Product`, `Shipping_Method`, `Supplier`, `Customer`, `Payment_Terms`, `Date`.
#    - **Ordinal** (if categorized): `Payment_Terms` (e.g., grouped by payment conditions).
#
# 3. **Numerical Variables**:
#    - **Integer**: `Quantity`.
#    - **Decimal**: `Value`, `Weight`.

# %% [markdown]
# # **Report**

# %% [markdown]
# # **Data Preprocessing**
#
# ## 1. **Data Description**
#
# ### 1.1 **Missing Data Statistics**
# - **Variables**: All columns in the dataset (`Transaction_ID`, `Country`, `Product`, `Import_Export`, etc.) have **0% missing values**, ensuring complete data across all attributes.
# - **Records**: Each transaction record in the dataset is complete with **0% missing data**.
# - **Imputation Requirement**: Not required as no data points are missing.
#
# ### 1.2 **Categorical Variable Encoding**
# - **Encoded Variables**:
#   The following categorical variables were converted into numerical representations for better compatibility with analytical and machine learning models:
#   - `Import_Export_code`
#   - `Category_code`
#   - `Shipping_Method_code`
#   - `Payment_Terms_code`
#
# ### 1.3 **Scaling of Numerical Variables**
# - **Scaled Variables**:
#   Continuous numerical variables have been scaled using **Min-Max Scaling** to normalize their range between 0 and 1. The affected variables are:
#   - `Quantity`
#   - `Value`
#   - `Weight`
#
# ---
#
# ## 2. **Objectives of Data Preprocessing**
#
# - **Completeness Assessment**: To confirm that the dataset has no missing values, ensuring robust analysis.
# - **Encoding Categorical Variables**: To transform categorical variables into numerical codes compatible with machine learning algorithms.
# - **Feature Scaling**: To standardize numerical data, ensuring that variables are comparable and enhancing the performance of machine learning models sensitive to scale.
#
# ---
#
# ## 3. **Key Observations**
#
# ### 3.1 **Missing Data Analysis**
# - The dataset has **no missing values** in any variable or transaction record.
#
# ### 3.2 **Categorical Variable Encoding**
# - All necessary categorical variables have been successfully encoded into ordinal representations, improving their suitability for analysis.
#
# ### 3.3 **Numerical Variable Scaling**
# - Numerical variables (`Quantity`, `Value`, `Weight`) were scaled effectively, ensuring consistent feature representation across different value ranges.
#
# ---
#
# ## 4. **Managerial Insights and Recommendations**
#
# - **Data Completeness**:
#   The absence of missing values ensures that preprocessing time is minimized and data integrity is preserved for downstream tasks.
#
# - **Feature Encoding**:
#   Encoded categorical variables must be interpreted correctly to align with business context, especially during model evaluation and result interpretation.
#
# - **Scaling**:
#   Scaled numerical variables are now optimized for use in machine learning models that are sensitive to feature magnitude, such as k-NN, SVM, and gradient-based methods.
#
# - **Next Steps**:
#   - Conduct **Exploratory Data Analysis (EDA)** to identify patterns, trends, and insights.
#   - Transition to **model development and training**, leveraging the preprocessed data for accurate and reliable predictions.

# %% [markdown]
# # **Descriptive and Inferential Statistics**
#
# ## 1. **Data Description**
# The dataset captures transactional details for imports and exports, encompassing categorical variables such as `Import_Export`, `Category`, `Shipping_Method`, and `Payment_Terms`, along with numerical attributes like `Quantity`, `Value`, and `Weight`. Data integrity is confirmed with no missing values. Statistical summaries and correlations are utilized to identify patterns, trends, and relationships among variables.
#
# ---
#
# ## 2. **Objectives**
# 1. Confirm data completeness and identify any missing values.
# 2. Analyze distributions and proportions of categorical variables.
# 3. Assess correlations and associations between variables to uncover potential relationships.
# 4. Evaluate numerical data characteristics, including range, central tendency, and dispersion.
# 5. Conduct normality tests to determine suitability for parametric modeling.
#
# ---
#
# ## 3. **Observations**
#
# ### 3.1 **Categorical Data Distribution**
# - **Import_Export**: Balanced distribution, with imports comprising 51% and exports 49%.
# - **Category**: Evenly distributed across categories, with Furniture as the most common (21%).
# - **Shipping_Method**: Distribution is equal across Sea, Land, and Air (each at 33%).
# - **Payment_Terms**: Four payment terms are represented, with "Cash on Delivery" being the most frequent (26%).
#
# ### 3.2 **Correlation Analysis**
# - Minimal to no correlation among categorical variables (`Import_Export`, `Category`, `Shipping_Method`, `Payment_Terms`).
# - Strong relationships observed among numerical variables, especially between `Weight` and other numerical features.
#
# ### 3.3 **Numerical Data Characteristics**
# - **Quantity**: Mean = 4987.49, Standard Deviation = 2834.22, Coefficient of Variation = 56.83%.
# - **Value**: Mean = 5056.83, Standard Deviation = 2883.52, Coefficient of Variation = 57.02%.
# - **Weight**: Mean = 2496.89, Standard Deviation = 1462.47, Coefficient of Variation = 58.57%.
#
# ### 3.4 **Chi-Square Test for Independence**
# - A statistically significant association was found between `Shipping_Method` and `Payment_Terms` (p-value = 0.0008).
#
# ### 3.5 **Normality Tests**
# - Numerical variables (`Quantity`, `Value`, `Weight`) are not normally distributed, as confirmed by the Shapiro-Wilk and Jarque-Bera tests.
#
# ---
#
# ## 4. **Managerial Insights**
#
# 1. **Data Completeness**: The dataset is well-prepared, requiring no additional preprocessing or imputation steps.
# 2. **Balanced Categorical Distribution**: Even distribution across categories and payment terms ensures robust comparative analysis.
# 3. **Numerical Data Correlations**: Strong relationships among numerical variables suggest potential interdependencies for predictive modeling.
# 4. **Non-Normality**: Transformations (e.g., log, square root) may be needed for models relying on normality assumptions.
# 5. **Operational Insights**: The significant association between `Shipping_Method` and `Payment_Terms` suggests possible operational or logistical alignment that warrants further investigation.
#
# ---
#
# ## 5. **Recommendations**
#
# 1. **Feature Engineering**: Leverage the strong correlations among numerical variables to enhance model performance.
# 2. **Data Transformation**: Apply transformations to non-normal variables to meet statistical assumptions where required.
# 3. **Operational Strategy**: Investigate the relationship between `Shipping_Method` and `Payment_Terms` to optimize logistics and payment processes.
# 4. **Category-Specific Analysis**: Perform stratified analyses across product categories and payment terms for tailored insights.
# 5. **Model Selection**: Utilize robust statistical or machine learning models (e.g., tree-based algorithms, non-parametric methods) that are resilient to non-normal distributions.
#
# ---

# %% [markdown]
# # **Unsupervised Learning: Cluster Analysis Report**
#
# ## **1. Description**
# Clustering analysis was conducted using **K-Means Clustering** and **Agglomerative Clustering** to segment the dataset into meaningful groups. The analysis considered attributes like `Quantity`, `Value`, `Weight`, and categorical encodings for `Import_Export`, `Category`, `Shipping_Method`, and `Payment_Terms`. To evaluate the effectiveness of clustering, **Silhouette Score** and **Davies-Bouldin Score** were calculated across 2 to 5 clusters.
#
# ---
#
# ## **2. Objectives**
# 1. Identify the optimal number of clusters for segmentation.
# 2. Evaluate cluster quality using internal validation metrics.
# 3. Provide actionable insights based on clustering outcomes.
#
# ---
#
# ## **3. Observations**
#
# ### **K-Means Clustering**
# | **Number of Clusters** | **Silhouette Score** | **Davies-Bouldin Score** |
# |-------------------------|----------------------|---------------------------|
# | 2                       | 0.2491              | 1.6150                   |
# | 3                       | 0.2432              | 1.3082                   |
# | 4                       | 0.2731              | 1.1315                   |
# | 5                       | 0.2654              | 1.1031                   |
#
# - **Optimal Clustering**:
#   - **4 Clusters**: Best Silhouette Score (0.2731) indicates clear separation and cohesion.
#   - **5 Clusters**: Lowest Davies-Bouldin Score (1.1031) suggests more compact clusters with slight improvement in segmentation.
#
# ### **Agglomerative Clustering**
# | **Number of Clusters** | **Silhouette Score** | **Davies-Bouldin Score** |
# |-------------------------|----------------------|---------------------------|
# | 2                       | 0.2112              | 1.7848                   |
# | 3                       | 0.2073              | 1.4009                   |
# | 4                       | 0.1976              | 1.3954                   |
# | 5                       | 0.1908              | 1.2443                   |
#
# - **Optimal Clustering**:
#   - **5 Clusters**: Achieves the lowest Davies-Bouldin Score (1.2443), denoting compact and distinct clusters.
#   - Silhouette Scores are consistently lower than K-Means, reflecting weaker overall separation.
#
# ---
#
# ## **4. Managerial Insights**
#
# ### **K-Means Clustering**
# 1. **Recommended Cluster Count**:
#    - **4 Clusters** balance separation and compactness, as evidenced by the highest Silhouette Score and competitive Davies-Bouldin Score.
#    - Suitable for operational scenarios requiring distinct and interpretable segmentation.
#
# 2. **Alternative Cluster Count**:
#    - **5 Clusters** offer finer granularity with marginal improvements in compactness (Davies-Bouldin Score).
#
# ### **Agglomerative Clustering**
# 1. **Recommended Cluster Count**:
#    - **5 Clusters** achieve the lowest Davies-Bouldin Score, making this configuration suitable for hierarchical and detailed segmentation.
#    - Lower Silhouette Scores across configurations suggest weaker separation compared to K-Means.
#
# 2. **Use Case**:
#    - Recommended for applications where hierarchical relationships among clusters (e.g., customer tiers, supply chain nodes) are important.
#
# ---
#
# ## **5. Recommendations**
#
# 1. **Adopt K-Means with 4 Clusters**:
#    - Optimal for scenarios requiring robust and interpretable segmentation.
#    - Facilitates clear identification of distinct groups for actionable decision-making.
#
# 2. **Leverage Agglomerative Clustering for Hierarchical Insights**:
#    - Use 5 clusters for deeper exploration of relationships within segments.
#
# 3. **Validation and Refinement**:
#    - Analyze intra-cluster and inter-cluster variability to validate segmentation.
#    - Align clustering outcomes with business objectives such as customer segmentation, inventory planning, or logistics optimization.
#
# 4. **Enhanced Feature Engineering**:
#    - Consider scaling additional features or applying domain knowledge for improved cluster separation.
#    - Reassess the influence of categorical variables to refine cluster definitions.
#
# 5. **Visualization for Insights**:
#    - Use dimensionality reduction techniques like **PCA** or **t-SNE** to visualize cluster boundaries and validate meaningful separations.
#    - Translate clusters into actionable strategies (e.g., customized marketing campaigns, operational efficiencies).

# %% [markdown]
# # **Supervised Learning: Classification Report**
#
# ## **1. Description of Data**
# The dataset contains 1001 records distributed across three target classes (0, 1, and 2). Each record includes numerical features representing attributes relevant to classification. The dataset is balanced across the target classes, ensuring fairness in model evaluation:
# - **Class Distribution**:
#   - Class 0: 336 samples
#   - Class 1: 322 samples
#   - Class 2: 343 samples
#
# ---
#
# ## **2. Objectives**
#
# ### **Primary Objective**
# - Build an accurate classification model to predict the target class (0, 1, or 2).
#
# ### **Secondary Objectives**
# 1. Compare the performance of **Decision Tree**, **Logistic Regression**, and **Random Forest** models.
# 2. Use evaluation metrics (Accuracy, Precision, Recall, F1-Score) to determine the best model.
# 3. Provide actionable insights based on model performance.
# 4. Recommend steps for future improvements.
#
# ---
#
# ## **3. Observations**
#
# ### **Decision Tree Model**
# - **Accuracy**: 0.33
# - **Performance Summary**:
#
# | Class | Precision | Recall | F1-Score | Support |
# |-------|-----------|--------|----------|---------|
# | 0     | 0.32      | 0.30   | 0.31     | 336     |
# | 1     | 0.32      | 0.34   | 0.33     | 322     |
# | 2     | 0.35      | 0.35   | 0.35     | 343     |
# | **Weighted Avg** | 0.33 | 0.33   | 0.33     | 1001    |
#
# ---
#
# ### **Logistic Regression Model**
# - **Accuracy**: 0.34
# - **Performance Summary**:
#
# | Class | Precision | Recall | F1-Score | Support |
# |-------|-----------|--------|----------|---------|
# | 0     | 0.32      | 0.10   | 0.16     | 336     |
# | 1     | 0.32      | 0.49   | 0.38     | 322     |
# | 2     | 0.37      | 0.43   | 0.40     | 343     |
# | **Weighted Avg** | 0.34 | 0.34   | 0.31     | 1001    |
#
# ---
#
# ### **Random Forest Model**
# - **Accuracy**: 0.33
# - **Performance Summary**:
#
# | Class | Precision | Recall | F1-Score | Support |
# |-------|-----------|--------|----------|---------|
# | 0     | 0.33      | 0.30   | 0.32     | 336     |
# | 1     | 0.31      | 0.34   | 0.33     | 322     |
# | 2     | 0.34      | 0.34   | 0.34     | 343     |
# | **Weighted Avg** | 0.33 | 0.33   | 0.33     | 1001    |
#
# ---
#
# ## **4. Managerial Insights**
#
# 1. **Logistic Regression**:
#    - Achieved the highest accuracy (0.34) among the models.
#    - Performed best on classifying **class 2**, with a relatively high F1-Score (0.40).
#    - Recommended for initial deployment due to simplicity and better accuracy.
#
# 2. **Decision Tree**:
#    - Accuracy (0.33) and performance metrics are moderate.
#    - Offers high interpretability, making it suitable for explainable decision-making scenarios.
#
# 3. **Random Forest**:
#    - Accuracy (0.33) is comparable to Decision Tree but lacks significant improvement.
#    - Due to computational complexity, it is less favorable for this dataset without further tuning.
#
# ---
#
# ## **5. Recommendations**
#
# ### **Model Deployment**
# 1. **Deploy Logistic Regression**:
#    - Logistic Regression demonstrated slightly better overall performance.
#    - Use this model for operational classification tasks, especially where interpretability is less critical.
#
# 2. **Alternative: Decision Tree for Explainability**:
#    - If model interpretability is a priority, use Decision Tree to gain actionable rules for decision-making.
#
# ---
#
# ### **Model Refinements**
# 1. **Feature Engineering**:
#    - Investigate feature importance and explore adding new features or transformations.
#    - Address the imbalance in precision and recall for classes 0 and 1 using resampling techniques or cost-sensitive models.
#
# 2. **Model Optimization**:
#    - Apply hyperparameter tuning (e.g., Grid Search or Random Search) to Logistic Regression and Decision Tree models for enhanced performance.
#    - Experiment with ensemble techniques like Gradient Boosting or XGBoost.
#
# 3. **Validation**:
#    - Validate models on a hold-out test set or through cross-validation to ensure robustness.
#
# ---
#
# ### **Future Steps**
# 1. **Explore Advanced Models**:
#    - Test Support Vector Machines (SVM) and Neural Networks for potential performance gains.
#    - Use unsupervised methods to preprocess data (e.g., PCA for dimensionality reduction).
#
# 2. **Business Alignment**:
#    - Collaborate with domain experts to interpret model outcomes and align them with business needs.
#    - Use model insights to refine operational strategies or identify actionable segments.
#
# ---

# %% [markdown]
# #Code

# %% [markdown]
# # Pre Processing Of Data

# %% [markdown]
# ## importing the necessary librarires

# %%
import pandas as pd, numpy as np # For Data Manipulation
import sklearn
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import seaborn as sns
from sklearn.tree import export_text
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import scipy.stats as sps # For Probability & Inferential Statistics
from scipy.stats import chi2_contingency
import requests
from io import StringIO
from scipy.stats import ttest_ind
import time
import pandas as pd
import numpy as np
from scipy import stats
import psutil
import os
import pandas as pd
import numpy as np
from scipy.stats import spearmanr, kendalltau
from scipy.stats import skew, kurtosis
from scipy.stats import pearsonr, spearmanr
from scipy.stats import sem, t
import pandas as pd
import statsmodels.stats.descriptivestats as dstats
import numpy as np  # For Data Manipulation
from sklearn.preprocessing import OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.impute import SimpleImputer  # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler  # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
import statsmodels.api as sm
import io
import requests
from scipy.stats import shapiro
from scipy.stats import spearmanr, kendalltau
from scipy.stats import skew, kurtosis, pearsonr, norm
from scipy.stats import chi2_contingency
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %% [markdown]
# ## Loading and categorizing the data

# %%
# Display All Columns of Dataset
pd.set_option('display.max_columns', None)

# %%
#2. Load the Data.
import pandas as pd
import requests
from io import StringIO

# Replace with your actual file ID
file_id = '1C6rWUEYUzTN0S071ytUFul9aBi9tqDQC'
#https://drive.google.com/file/d/1C6rWUEYUzTN0S071ytUFul9aBi9tqDQC/view?usp=sharing
# Construct the URL
url = f'https://drive.google.com/uc?id={file_id}'

# Fetch the data using requests
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad responses

# Read the data into a pandas DataFrame using StringIO
mb25_df = pd.read_csv(StringIO(response.text))

# Display the first few rows of the DataFrame
mb25_df.head(20)
# Out:
#                           Transaction_ID                      Country  \
# 0   e3e70682-c209-4cac-a29f-6fbed82c07cd                     Colombia
# 1   f728b4fa-4248-4e3a-8a5d-2f346baa9455                        Chile
# 2   eb1167b3-67a9-4378-bc65-c1e582e2e662                       Turkey
# 3   f7c1bd87-4da5-4709-9471-3d60c8a70639             Christmas Island
# 4   e443df78-9558-467f-9ba9-1faf7a024204                      Finland
# 5   23a7711a-8133-4876-b7eb-dcd9e87a1613                  New Zealand
# 6   1846d424-c17c-4279-a3c6-612f48268673  Falkland Islands (Malvinas)
# 7   fcbd04c3-4021-4ef7-8ca5-a5a19e4d6e3c                   Bangladesh
# 8   b4862b21-fb97-4435-8856-1712e8e5216a                      Burundi
# 9   259f4329-e6f4-490b-9a16-4106cf6a659e                    Nicaragua
# 10  12e0c8b2-bad6-40fb-9948-8dec4f65d4d9                        Italy
# 11  5487ce1e-af19-422a-99b8-a714e61a441c                      Burundi
# ...

# %%
#7. Display the Dimensions of Sample Data.
mb25_sdf = mb25_df.sample(n=5001, random_state=55025)
print(mb25_sdf.shape)
# Out:
# (5001, 16)

# %%
#8. Display Sample Data Information.
print("\nInformation about the Sample DataFrame:")
mb25_sdf.info()
# Out:
# Information about the Sample DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 13600 to 464
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# ...

# %%
mb25_sdf.columns
# Out:
# Index(['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity',
#        'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight',
#        'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number',
#        'Payment_Terms'],
#       dtype='object')

# %%
# Data Bifurcation
mb25_sdf_cat = mb25_sdf[['Country', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer', 'Payment_Terms']] # Categorical Data [Nominal | Ordinal]
mb25_sdf_noncat=mb25_sdf[['Quantity', 'Value', 'Weight']]# Non-Categorical Data

# %%
#to find out te relevant categorical variables
for column in mb25_sdf_cat.columns:
    grouped_data = mb25_sdf_cat.groupby(column).size().reset_index(name='counts')
    print(f"Grouped by {column}:\n{grouped_data}\n")
# Out:
# Grouped by Country:
#                Country  counts
# 0          Afghanistan      12
# 1              Albania      19
# 2              Algeria      24
# 3       American Samoa      21
# 4              Andorra       6
# ..                 ...     ...
# 238  Wallis and Futuna      22
# 239     Western Sahara      21
# 240              Yemen      16
# 241             Zambia      17
# 242           Zimbabwe      15
#
# [243 rows x 2 columns]
#
# Grouped by Import_Export:
#   Import_Export  counts
# 0        Export    2469
# 1        Import    2532
#
# Grouped by Category:
#       Category  counts
# 0     Clothing    1000
# 1  Electronics     961
# 2    Furniture    1020
# 3    Machinery    1002
# 4         Toys    1018
#
# Grouped by Port:
#              Port  counts
# 0     Abigailfort       1
# 1     Abigailland       1
# 2     Abigailview       1
# 3     Acevedofort       1
# 4      Acevedoton       1
# ...           ...     ...
# 4318   Youngville       1
# ...

# %%
#Relevant categorical variable
# Data Bifurcation
mb25_sdf_cat = mb25_sdf[[ 'Import_Export', 'Category', 'Shipping_Method',  'Payment_Terms']] # Categorical Data [Nominal | Ordinal]
mb25_sdf_noncat=mb25_sdf[['Quantity', 'Value', 'Weight']]# Non-Categorical Data

# %%
mb25_sdf_cat.head()
# Out:
#       Import_Export     Category Shipping_Method     Payment_Terms
# 13600        Export     Clothing             Sea           Prepaid
# 3291         Import    Furniture             Sea            Net 30
# 13497        Import  Electronics             Sea  Cash on Delivery
# 2630         Export     Clothing             Air  Cash on Delivery
# 2141         Export    Machinery            Land  Cash on Delivery

# %%
mb25_sdf_noncat.head()
# Out:
#        Quantity    Value   Weight
# 13600        48  8420.92  4148.20
# 3291       9371  9197.25   349.35
# 13497      2462  1140.35  1815.14
# 2630       9961   574.55  1345.48
# 2141        690   137.30  1797.07

# %% [markdown]
# ## Missing Data Report

# %%
# Calculate missing data statistics for each variable
missing_data = mb25_sdf.isnull().sum()
total_records = len(mb25_sdf)

# Calculate percentage of missing data
percentage_missing = (missing_data / total_records) * 100

# Create a DataFrame to display the results
missing_data_summary = pd.DataFrame({
    'Variable': missing_data.index,
    'Missing Count': missing_data.values,
    'Percentage Missing': percentage_missing.values
})

# Display the summary
print("Missing Data Statistics:\n", missing_data_summary)
# Out:
# Missing Data Statistics:
#             Variable  Missing Count  Percentage Missing
# 0    Transaction_ID              0                 0.0
# 1           Country              0                 0.0
# 2           Product              0                 0.0
# 3     Import_Export              0                 0.0
# 4          Quantity              0                 0.0
# 5             Value              0                 0.0
# 6              Date              0                 0.0
# 7          Category              0                 0.0
# 8              Port              0                 0.0
# 9      Customs_Code              0                 0.0
# 10           Weight              0                 0.0
# 11  Shipping_Method              0                 0.0
# 12         Supplier              0                 0.0
# 13         Customer              0                 0.0
# 14   Invoice_Number              0                 0.0
# 15    Payment_Terms              0                 0.0

# %%
# Calculate missing data statistics for each record
record_missing_data = mb25_sdf.isnull().sum(axis=1)
total_columns = mb25_sdf.shape[1]

# Calculate percentage of missing data for each record
percentage_missing_record = (record_missing_data / total_columns) * 100

# Create a DataFrame to display the results
missing_data_record_summary = pd.DataFrame({
    'Record Index': mb25_sdf.index,
    'Missing Count': record_missing_data.values,
    'Percentage Missing': percentage_missing_record.values
})

# Display the summary
print("Record-wise Missing Data Statistics:\n", missing_data_record_summary)
# Out:
# Record-wise Missing Data Statistics:
#        Record Index  Missing Count  Percentage Missing
# 0            13600              0                 0.0
# 1             3291              0                 0.0
# 2            13497              0                 0.0
# 3             2630              0                 0.0
# 4             2141              0                 0.0
# ...            ...            ...                 ...
# 4996          3555              0                 0.0
# 4997          4304              0                 0.0
# 4998         13649              0                 0.0
# 4999          6220              0                 0.0
# 5000           464              0                 0.0
#
# [5001 rows x 3 columns]

# %%
mb25_cat_mdi = mb25_sdf_cat

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Categorical Data Descreptive Statistics

# %%
#For Categorical Data
for i in mb25_sdf_cat:
  mb25_count_stats = pd.concat([mb25_sdf_cat[i].value_counts(), mb25_sdf_cat[i].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
  print(i," : \n ",mb25_count_stats,"\n")
# Out:
# Import_Export  :
#     Import_Export  count  percentage
# 0        Import   2532        51.0
# 1        Export   2469        49.0
#
# Category  :
#         Category  count  percentage
# 0    Furniture   1020        20.0
# 1         Toys   1018        20.0
# 2    Machinery   1002        20.0
# 3     Clothing   1000        20.0
# 4  Electronics    961        19.0
#
# Shipping_Method  :
#     Shipping_Method  count  percentage
# 0             Sea   1712        34.0
# 1             Air   1667        33.0
# 2            Land   1622        32.0
#
# Payment_Terms  :
#         Payment_Terms  count  percentage
# 0            Net 60   1332        27.0
# 1  Cash on Delivery   1260        25.0
# 2           Prepaid   1232        25.0
# 3            Net 30   1177        24.0

# %%
# Spearman and Kendall's Ranl correlation


# Create an empty DataFrame to store the results
correlation_results = pd.DataFrame(index=mb25_sdf_cat.columns,
                                    columns=['Spearman', 'Kendall'])

# Loop through each pair of columns in the DataFrame
for col1 in mb25_sdf_cat.columns:
    for col2 in mb25_sdf_cat.columns:
        if col1 != col2:  # Avoid calculating correlation with itself
            # Calculate Spearman's rank correlation
            spearman_corr, _ = spearmanr(mb25_sdf_cat[col1],
                                         mb25_sdf_cat[col2],
                                         nan_policy='omit')  # Handle missing values

            # Calculate Kendall's rank correlation
            kendall_corr, _ = kendalltau(mb25_sdf_cat[col1],
                                         mb25_sdf_cat[col2],
                                         nan_policy='omit')  # Handle missing values

            # Store the results in the DataFrame
            correlation_results.loc[col1, 'Spearman'] = spearman_corr
            correlation_results.loc[col1, 'Kendall'] = kendall_corr

# Display the results
print("Correlation Results:\n", correlation_results)
# Out:
# Correlation Results:
#                   Spearman   Kendall
# Import_Export   -0.002976 -0.002717
# Category         0.010615  0.008657
# Shipping_Method  0.010158    0.0088
# Payment_Terms    0.010158    0.0088

# %% [markdown]
# ### Non Categorical Descreptive Statistics

# %%
#basic descreptive statistics non categorical data

# Create an empty dictionary to store the results
central_tendency_results = {}

# Loop through each column in the DataFrame
for column in mb25_sdf_noncat.columns:
    # Calculate measures of central tendency
    minimum = mb25_sdf_noncat[column].min()
    maximum = mb25_sdf_noncat[column].max()
    mean = mb25_sdf_noncat[column].mean()
    median = mb25_sdf_noncat[column].median()
    mode = mb25_sdf_noncat[column].mode()[0]  # Get the first mode if multiple exist
    percentile_25 = np.percentile(mb25_sdf_noncat[column], 25)  # 25th percentile
    percentile_75 = np.percentile(mb25_sdf_noncat[column], 75)  # 75th percentile

    # Store the results in the dictionary
    central_tendency_results[column] = {
        'Minimum': minimum,
        'Maximum': maximum,
        'Mean': mean,
        'Median': median,
        'Mode': mode,
        '25th Percentile': percentile_25,
        '75th Percentile': percentile_75
    }

# Display the results
for column, stats in central_tendency_results.items():
    print(f"Variable: {column}")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)
# Out:
# Variable: Quantity
#   Minimum: 3
#   Maximum: 9996
#   Mean: 4941.634273145371
#   Median: 4903.0
#   Mode: 3426
#   25th Percentile: 2488.0
#   75th Percentile: 7397.0
# --------------------
# Variable: Value
#   Minimum: 102.12
#   Maximum: 9998.07
#   Mean: 5029.336024795041
#   Median: 5108.57
#   Mode: 339.28
#   25th Percentile: 2495.66
#   75th Percentile: 7506.18
# --------------------
# Variable: Weight
#   Minimum: 2.59
#   Maximum: 4999.93
#   Mean: 2482.289712057589
#   Median: 2433.72
#   Mode: 84.94
#   25th Percentile: 1230.35
#   75th Percentile: 3714.34
# --------------------

# %%
# Create an empty dictionary to store the results
dispersion_results = {}

# Loop through each column in the DataFrame
for column in mb25_sdf_noncat.columns:
    # Calculate measures of dispersion
    data = mb25_sdf_noncat[column].dropna()  # Remove missing values for calculations
    range_val = data.max() - data.min()
    std_dev = data.std()
    skewness = skew(data)
    kurtosis_val = kurtosis(data)

    # Store the results in the dictionary
    dispersion_results[column] = {
        'Range': range_val,
        'Standard Deviation': std_dev,
        'Skewness': skewness,
        'Kurtosis': kurtosis_val
    }

# Display the results
for column, stats in dispersion_results.items():
    print(f"Variable: {column}")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)
# Out:
# Variable: Quantity
#   Range: 9993
#   Standard Deviation: 2867.6043220111656
#   Skewness: 0.029176660276943815
#   Kurtosis: -1.1737459936507308
# --------------------
# Variable: Value
#   Range: 9895.949999999999
#   Standard Deviation: 2874.2586578366177
#   Skewness: -0.009062278440822637
#   Kurtosis: -1.209034054594197
# --------------------
# Variable: Weight
#   Range: 4997.34
#   Standard Deviation: 1445.5902650989442
#   Skewness: 0.042271064106562055
#   Kurtosis: -1.2089915208816422
# --------------------

# %%
# Pearson and Spearman correlation

# Create an empty DataFrame to store the results
correlation_results = pd.DataFrame(index=mb25_sdf_noncat.columns,
                                    columns=['Pearson', 'Spearman'])

# Loop through each pair of columns in the DataFrame
for col1 in mb25_sdf_noncat.columns:
    for col2 in mb25_sdf_noncat.columns:
        if col1 != col2:  # Avoid calculating correlation with itself
            # Calculate Pearson correlation
            pearson_corr, _ = pearsonr(mb25_sdf_noncat[col1],
                                       mb25_sdf_noncat[col2])

            # Calculate Spearman correlation
            spearman_corr, _ = spearmanr(mb25_sdf_noncat[col1],
                                         mb25_sdf_noncat[col2],
                                         nan_policy='omit')  # Handle missing values

            # Store the results in the DataFrame
            correlation_results.loc[col1, 'Pearson'] = pearson_corr
            correlation_results.loc[col1, 'Spearman'] = spearman_corr

# Display the results
print("Correlation Results:\n", correlation_results)
# Out:
# Correlation Results:
#             Pearson  Spearman
# Quantity  0.005363  0.005768
# Value     0.017721  0.017381
# Weight    0.017721  0.017381

# %%
# coefficient of variation and confidence interval

# Create an empty dictionary to store the results
composite_results = {}

# Loop through each column in the DataFrame
for column in mb25_sdf_noncat.columns:
    # Calculate measures
    data = mb25_sdf_noncat[column].dropna()  # Remove missing values for calculations

    # Coefficient of Variation
    cv = (data.std() / data.mean()) * 100

    # Confidence Interval (95% confidence level)
    confidence_level = 0.95
    degrees_of_freedom = len(data) - 1

    # Calculate standard error of the mean
    sem_val = sem(data)

    # Calculate confidence interval
    confidence_interval = t.interval(confidence_level,
                                     degrees_of_freedom,
                                     loc=data.mean(),
                                     scale=sem_val)

    # Store the results in the dictionary
    composite_results[column] = {
        'Coefficient of Variation': cv,
        'Confidence Interval (95%)': confidence_interval
    }

# Display the results
for column, stats in composite_results.items():
    print(f"Variable: {column}")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)
# Out:
# Variable: Quantity
#   Coefficient of Variation: 58.02947291333892
#   Confidence Interval (95%): (4862.138500772995, 5021.130045517746)
# --------------------
# Variable: Value
#   Coefficient of Variation: 57.14986319598224
#   Confidence Interval (95%): (4949.655780819659, 5109.016268770423)
# --------------------
# Variable: Weight
#   Coefficient of Variation: 58.23616228504945
#   Confidence Interval (95%): (2442.21503586327, 2522.364388251908)
# --------------------

# %% [markdown]
# ## Data Vizualization

# %% [markdown]
# ### Categorical  Data Vizualization

# %%
#bar chart

grouped_data = mb25_sdf.groupby('Import_Export')['Value'].sum().reset_index()

# Create the bar graph
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.bar(grouped_data['Import_Export'], grouped_data['Value'])

# Add labels and title
plt.xlabel('Import/Export Category')
plt.ylabel('Total Value')
plt.title('Total Value by Import/Export Category')

# Rotate x-axis labels if needed
plt.xticks(rotation=45, ha='right')  # Adjust rotation and alignment as needed

# Show the graph
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming mb25_sdf_cat is your DataFrame

# Get the value counts of 'Payment_Terms'
payment_counts = mb25_sdf_cat['Payment_Terms'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.pie(payment_counts, labels=payment_counts.index, autopct='%1.1f%%', startangle=90)

# Add title
plt.title('Distribution of Payment Methods')

# Ensure the circle's proportion is correct
plt.axis('equal')

# Show the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# Assuming mb25_sdf is your DataFrame and contains 'Date', 'Import_Export', and 'Value' columns

# Convert 'Date' column to datetime, specifying the correct format
mb25_sdf['Date'] = pd.to_datetime(mb25_sdf['Date'], format='%d-%m-%Y')

# Extract year from 'Date' column
mb25_sdf['Year'] = mb25_sdf['Date'].dt.year

# Calculate average value for each year
average_value_by_year = mb25_sdf.groupby('Year')['Value'].mean()

# Create the line chart
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(average_value_by_year.index, average_value_by_year.values)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.title('Average Import and Export Value over Time')

# Rotate x-axis labels if needed
plt.xticks(rotation=45, ha='right')  # Adjust rotation and alignment as needed

# Show the chart
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# ### Non-Categorical Vizualisation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Value', data=mb25_sdf, showfliers=True)

# Display the plot
plt.title('Box Plot of Value by Category')
plt.show()

# %% [markdown]
# ## Inferetial Statistics

# %% [markdown]
# ### Categorical Inferential Statitics

# %%
# Assuming mb25_sdf is your DataFrame with the relevant columns
mb25_sdf_cat = mb25_sdf[['Import_Export', 'Category', 'Shipping_Method', 'Payment_Terms']]

# Function to run Chi-square test for homogeneity
def chi_square_test_of_homogeneity(df, columns):
    results = {}
    for i in range(len(columns)):
        for j in range(i + 1, len(columns)):
            col1 = columns[i]
            col2 = columns[j]
            contingency_table = pd.crosstab(df[col1], df[col2])

            # Perform Chi-square test
            chi2, p, dof, expected = chi2_contingency(contingency_table)

            results[f"{col1} vs {col2}"] = {
                "Chi2": chi2,
                "p-value": p,
                "Degrees of Freedom": dof,
                "Expected Frequencies": expected
            }
    return results

# Example usage
chi_square_results = chi_square_test_of_homogeneity(mb25_sdf_cat, mb25_sdf_cat.columns)

# Print results
for comparison, stats in chi_square_results.items():
    print(f"\n{comparison}:")
    for key, value in stats.items():
        if key == "Expected Frequencies":
            print(f"{key}:\n{value}")
        else:
            print(f"{key}: {value}")
# Out:
# Import_Export vs Category:
# Chi2: 2.102356260618488
# p-value: 0.7169395120291728
# Degrees of Freedom: 4
# Expected Frequencies:
# [[493.70125975 474.44691062 503.57528494 494.68866227 502.58788242]
#  [506.29874025 486.55308938 516.42471506 507.31133773 515.41211758]]
#
# Import_Export vs Shipping_Method:
# Chi2: 14.279063942794753
# p-value: 0.0007931232139624317
# Degrees of Freedom: 2
# Expected Frequencies:
# [[823.         800.78344331 845.21655669]
#  [844.         821.21655669 866.78344331]]
#
# Import_Export vs Payment_Terms:
# Chi2: 2.4795500432646076
# p-value: 0.4789981876211832
# Degrees of Freedom: 3
# Expected Frequencies:
# [[622.06358728 581.08638272 657.61007798 608.23995201]
#  [637.93641272 595.91361728 674.38992202 623.76004799]]
#
# Category vs Shipping_Method:
# Chi2: 8.958491356523309
# p-value: 0.3458096838687905
# Degrees of Freedom: 8
# Expected Frequencies:
# [[333.33333333 324.33513297 342.33153369]
#  [320.33333333 311.68606279 328.98060388]
# ...

# %% [markdown]
# ### Non Categorical Inferential Statistics

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Assuming 'mb25_sdf_noncat' is already defined as a DataFrame with non-categorical columns

alpha = 0.05  # Significance level

# Loop through each column in the DataFrame
for column in mb25_sdf_noncat.columns:
    data = mb25_sdf_noncat[column].dropna()  # Remove missing values for calculations

    print(f"Variable: {column}")

    # Shapiro-Wilk Test
    shapiro_stat, shapiro_p = stats.shapiro(data)
    print(f"  Shapiro-Wilk Test: statistic={shapiro_stat:.3f}, p-value={shapiro_p:.3f}, ", end="")
    if shapiro_p > alpha:
        print("Data is normally distributed (fail to reject H0)")
    else:
        print("Data is not normally distributed (reject H0)")

    # Kolmogorov-Smirnov Test
    ks_stat, ks_p = stats.kstest(data, 'norm')
    print(f"  Kolmogorov-Smirnov Test: statistic={ks_stat:.3f}, p-value={ks_p:.3f}, ", end="")
    if ks_p > alpha:
        print("Data is normally distributed (fail to reject H0)")
    else:
        print("Data is not normally distributed (reject H0)")

    # Anderson-Darling Test
    anderson_result = stats.anderson(data, dist='norm')
    print(f"  Anderson-Darling Test: statistic={anderson_result.statistic:.3f}, ", end="")
    if anderson_result.statistic < anderson_result.critical_values[2]:  # Using critical value for alpha=0.05
        print("Data is normally distributed (fail to reject H0)")
    else:
        print("Data is not normally distributed (reject H0)")

    # Jarque-Bera Test
    jb_stat, jb_p = stats.jarque_bera(data)
    print(f"  Jarque-Bera Test: statistic={jb_stat:.3f}, p-value={jb_p:.3f}, ", end="")
    if jb_p > alpha:
        print("Data is normally distributed (fail to reject H0)")
    else:
        print("Data is not normally distributed (reject H0)")

    print("-" * 20)
# Out:
# Variable: Quantity
#   Shapiro-Wilk Test: statistic=0.957, p-value=0.000, Data is not normally distributed (reject H0)
#   Kolmogorov-Smirnov Test: statistic=1.000, p-value=0.000, Data is not normally distributed (reject H0)
#   Anderson-Darling Test: statistic=51.126, Data is not normally distributed (reject H0)
#   Jarque-Bera Test: statistic=287.784, p-value=0.000, Data is not normally distributed (reject H0)
# --------------------
# Variable: Value
#   Shapiro-Wilk Test: statistic=0.953, p-value=0.000, Data is not normally distributed (reject H0)
#   Kolmogorov-Smirnov Test: statistic=1.000, p-value=0.000, Data is not normally distributed (reject H0)
#   Anderson-Darling Test: statistic=57.732, Data is not normally distributed (reject H0)
#   Jarque-Bera Test: statistic=304.663, p-value=0.000, Data is not normally distributed (reject H0)
# --------------------
# Variable: Weight
#   Shapiro-Wilk Test: statistic=0.953, p-value=0.000, Data is not normally distributed (reject H0)
# ...

# %%
# Test of Correlation {t}

# Loop through all pairs of columns
for col1 in mb25_sdf_noncat.columns:
    for col2 in mb25_sdf_noncat.columns:
        if col1 != col2:  # Avoid comparing a column with itself
            # Remove missing values for valid calculations
            data1 = mb25_sdf_noncat[col1].dropna()
            data2 = mb25_sdf_noncat[col2].dropna()

            # Perform t-test for correlation
            t_statistic, p_value = ttest_ind(data1, data2)

            # Print results
            print(f"Correlation between {col1} and {col2}:")
            print(f"  t-statistic: {t_statistic:.3f}")
            print(f"  p-value: {p_value:.3f}")
            print("-" * 20)
# Out:
# Correlation between Quantity and Value:
#   t-statistic: -1.528
#   p-value: 0.127
# --------------------
# Correlation between Quantity and Weight:
#   t-statistic: 54.157
#   p-value: 0.000
# --------------------
# Correlation between Value and Quantity:
#   t-statistic: 1.528
#   p-value: 0.127
# --------------------
# Correlation between Value and Weight:
#   t-statistic: 55.985
#   p-value: 0.000
# --------------------
# Correlation between Weight and Quantity:
#   t-statistic: -54.157
#   p-value: 0.000
# --------------------
# Correlation between Weight and Value:
#   t-statistic: -55.985
#   p-value: 0.000
# --------------------

# %% [markdown]
# ## Numerical Encoding of Categorical Data

# %%
oe = OrdinalEncoder()
oe_fit = oe.fit_transform( mb25_cat_mdi)
mb25_cat_code = pd.DataFrame(oe_fit, columns=['Import_Export_code', 'Category_code', 'Shipping_Method_code', 'Payment_Terms_code'])
mb25_cat_mdt_code_oe =   mb25_cat_code;  mb25_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
# mb25_cat_mdt_code_oe = pd.merge( mb25_cat_mdt_code,  mb25_cat_code_oe, left_index=True, right_index=True);  mb25_cat_mdt_code_oe
# Out:
#       Import_Export_code  Category_code  Shipping_Method_code  \
# 0                    0.0            0.0                   2.0
# 1                    1.0            2.0                   2.0
# 2                    1.0            1.0                   2.0
# 3                    0.0            0.0                   0.0
# 4                    0.0            3.0                   1.0
# ...                  ...            ...                   ...
# 4996                 1.0            2.0                   2.0
# 4997                 1.0            2.0                   2.0
# 4998                 1.0            2.0                   0.0
# 4999                 1.0            2.0                   2.0
# 5000                 1.0            4.0                   0.0
#
#       Payment_Terms_code
# 0                    3.0
# 1                    1.0
# 2                    0.0
# 3                    0.0
# 4                    0.0
# ...                  ...
# 4996                 2.0
# ...

# %% [markdown]
# ## Scaling Of Non Categorical Data

# %%
scaled = MinMaxScaler()

mb25_noncat_scaled = scaled.fit_transform(mb25_sdf_noncat)

# Convert the scaled data back to a DataFrame
mb25_noncat_scaled = pd.DataFrame(mb25_noncat_scaled, columns=mb25_sdf_noncat.columns)

# Display the scaled data
print(mb25_noncat_scaled.head())
# Out:
#    Quantity     Value    Weight
# 0  0.004503  0.840627  0.829563
# 1  0.937456  0.919076  0.069389
# 2  0.246072  0.104915  0.362703
# 3  0.996498  0.047740  0.268721
# 4  0.068748  0.003555  0.359087

# %%
#combining of numerically encoded categorical and scaled non categorical line

mb25_sdf_clean = pd.concat([mb25_noncat_scaled, mb25_cat_mdt_code_oe], axis=1)
mb25_sdf_clean.head()
# Out:
#    Quantity     Value    Weight  Import_Export_code  Category_code  \
# 0  0.004503  0.840627  0.829563                 0.0            0.0
# 1  0.937456  0.919076  0.069389                 1.0            2.0
# 2  0.246072  0.104915  0.362703                 1.0            1.0
# 3  0.996498  0.047740  0.268721                 0.0            0.0
# 4  0.068748  0.003555  0.359087                 0.0            3.0
#
#    Shipping_Method_code  Payment_Terms_code
# 0                   2.0                 3.0
# 1                   2.0                 1.0
# 2                   2.0                 0.0
# 3                   0.0                 0.0
# 4                   1.0                 0.0

# %% [markdown]
# # Data Bifurcation [Training & Testing Datasets]

# %%
# Dataset Used : sdf_ppd

train_sdf, test_sdf = train_test_split(mb25_sdf_clean, test_size=0.25, random_state=55025)
#train_sdf # Training Dataset
#test_sdf # Testing Dataset

# %% [markdown]
# # Unsupervised Learning (Clustering)

# %% [markdown]
# ## K-means

# %%
mb25_importexport_subset = mb25_sdf_clean
# 1. Select numerical features for clustering
mb25_cluster_data = mb25_importexport_subset[['Quantity', 'Value', 'Weight']]

# %%
# 2.1.3. K-Means Clustering Model Evaluation [K=2 | K=3]
# ------------------------------------------------------
# Assuming mb25_importexport_subset and mb25_cluster_data are defined as in previous cells

# Perform K-Means clustering with 2 clusters
mb25_km_2cluster_model = KMeans(n_clusters=2, init='random', random_state=55025).fit(mb25_cluster_data)  # Define the model and fit it

mb25_sscore_km_2cluster = sscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_km_2cluster_model.labels_);  # Use the fitted model's labels
mb25_sscore_km_2cluster
print("Silhouette Score (2 Clusters):", mb25_sscore_km_2cluster)
mb25_dbscore_km_2cluster = dbscore(mb25_importexport_subset[['Quantity','Value','Weight']], mb25_km_2cluster_model.labels_)
mb25_dbscore_km_2cluster
print("Davies-Bouldin Score (2 Clusters):", mb25_dbscore_km_2cluster)
# Out:
# Silhouette Score (2 Clusters): 0.24576205789183891
# Davies-Bouldin Score (2 Clusters): 1.6331895578093834

# %%
# Perform K-Means clustering with 3 clusters and evaluate
mb25_km_3cluster_model = KMeans(n_clusters=3, init='random', random_state=55025).fit(mb25_cluster_data)  # Define and fit the model with 3 clusters

# Calculate Silhouette Score for 3 clusters
#mb25_sscore_km_3cluster = sscore(mb25_ds_subset, mb25_km_3cluster_model); mb25_sscore_km_3cluster # Original line causing error
mb25_sscore_km_3cluster = sscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_km_3cluster_model.labels_)  # Use mb25_importexport_subset and labels from 3-cluster model
print("Silhouette Score (3 Clusters):", mb25_sscore_km_3cluster)

# Calculate Davies-Bouldin Score for 3 clusters
#mb25_dbscore_km_3cluster = dbscore(mb25_ds_subset, mb25_km_3cluster_model); mb25_dbscore_km_3cluster # Original line causing error
mb25_dbscore_km_3cluster = dbscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_km_3cluster_model.labels_)  # Use mb25_importexport_subset and labels from 3-cluster model
print("Davies-Bouldin Score (3 Clusters):", mb25_dbscore_km_3cluster)
# Out:
# Silhouette Score (3 Clusters): 0.24646322931547568
# Davies-Bouldin Score (3 Clusters): 1.307205475048927

# %%
# Perform K-Means clustering with 4 clusters
mb25_km_4cluster_model = KMeans(n_clusters=4, init='random', random_state=55025).fit(mb25_cluster_data)  # Define and fit the model with 4 clusters

# Calculate Silhouette Score for 4 clusters
mb25_sscore_km_4cluster = sscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_km_4cluster_model.labels_)  # Use mb25_importexport_subset and labels from 4-cluster model
print("Silhouette Score (4 Clusters):", mb25_sscore_km_4cluster)

# Calculate Davies-Bouldin Score for 4 clusters
mb25_dbscore_km_4cluster = dbscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_km_4cluster_model.labels_)  # Use mb25_importexport_subset and labels from 4-cluster model
print("Davies-Bouldin Score (4 Clusters):", mb25_dbscore_km_4cluster)
# Out:
# Silhouette Score (4 Clusters): 0.2754493662011996
# Davies-Bouldin Score (4 Clusters): 1.1154871916506248

# %%
# Perform K-Means clustering with 5 clusters
mb25_km_5cluster_model = KMeans(n_clusters=5, init='random', random_state=55025).fit(mb25_cluster_data)  # Define and fit the model with 5 clusters

# Calculate Silhouette Score for 5 clusters
mb25_sscore_km_5cluster = sscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_km_5cluster_model.labels_)  # Use mb25_importexport_subset and labels from 5-cluster model
print("Silhouette Score (5 Clusters):", mb25_sscore_km_5cluster)

# Calculate Davies-Bouldin Score for 5 clusters
mb25_dbscore_km_5cluster = dbscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_km_5cluster_model.labels_)  # Use mb25_importexport_subset and labels from 5-cluster model
print("Davies-Bouldin Score (5 Clusters):", mb25_dbscore_km_5cluster)
# Out:
# Silhouette Score (5 Clusters): 0.2699951408210265
# Davies-Bouldin Score (5 Clusters): 1.0700706546303629

# %%
#since 4 cluster was appropriate
# Create a KMeans Cluster Member Dataframe

# Assuming 'mb25_importexport_subset' contains the data you want to cluster
mb25_ds_subset_KMeanster = mb25_importexport_subset.copy()  # Use mb25_importexport_subset instead of mb25_ds_subset
mb25_ds_subset_KMeanster.reset_index(level=0, inplace=True, names='index')
mb25_ds_subset_KMeanster['cluster_number'] = mb25_km_4cluster_model.labels_  # Assign cluster labels instead of the model object
mb25_ds_subset_KMeanster.sort_values('cluster_number', inplace=True)

# Display the DataFrame
mb25_ds_subset_KMeanster
# Out:
#       index  Quantity     Value    Weight  Import_Export_code  Category_code  \
# 3565   3565  0.475933  0.222961  0.795817                 1.0            0.0
# 930     930  0.599320  0.050866  0.730653                 0.0            3.0
# 3641   3641  0.683178  0.071647  0.177228                 0.0            4.0
# 928     928  0.920144  0.331658  0.955300                 1.0            2.0
# 2543   2543  0.847193  0.153147  0.674833                 1.0            0.0
# ...     ...       ...       ...       ...                 ...            ...
# 3400   3400  0.550485  0.407344  0.050563                 1.0            1.0
# 3396   3396  0.442710  0.778572  0.322666                 0.0            4.0
# 1097   1097  0.932353  0.668303  0.262091                 0.0            0.0
# 1085   1085  0.366356  0.870289  0.356702                 1.0            2.0
# 3490   3490  0.926148  0.761549  0.236506                 1.0            3.0
#
# ...

# %%
# Plot the K-Means Clustered Data


# Cluster Model Used : km_4cluster_model

mb25_cluster_labels = list(mb25_ds_subset_KMeanster['cluster_number'].unique())

# Using 'Quantity' and 'Value' for the scatter plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
mb25_scatter_plot = plt.scatter(x='Quantity', y='Value', data=mb25_ds_subset_KMeanster, c='cluster_number', cmap='brg')
plt.legend(handles=mb25_scatter_plot.legend_elements()[0], labels=mb25_cluster_labels)
plt.xlabel('Quantity')
plt.ylabel('Value')
plt.title('Import/Export: Value vs Quantity Scatter Plot : K-Means Clusters')
plt.grid()
plt.show()

# %% [markdown]
# ## Anglomerative Hierarchy Clustering

# %%
# 2 Cluster

# Perform Agglomerative Clustering with 2 clusters
mb25_ag_2cluster_model = AgglomerativeClustering(n_clusters=2).fit(mb25_importexport_subset[['Quantity', 'Value', 'Weight']])  # Define and fit the model

# Calculate Silhouette Score for 2 clusters
mb25_sscore_ag_2cluster = sscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_ag_2cluster_model.labels_)
print("Silhouette Score (2 Clusters - Agglomerative):", mb25_sscore_ag_2cluster)

# Calculate Davies-Bouldin Score for 2 clusters
mb25_dbscore_ag_2cluster = dbscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_ag_2cluster_model.labels_)
print("Davies-Bouldin Score (2 Clusters - Agglomerative):", mb25_dbscore_ag_2cluster)
# Out:
# Silhouette Score (2 Clusters - Agglomerative): 0.21681587279089326
# Davies-Bouldin Score (2 Clusters - Agglomerative): 1.7687222733948589

# %%
# 3 Cluster

# Perform Agglomerative Clustering with 3 clusters
mb25_ag_3cluster_model = AgglomerativeClustering(n_clusters=3).fit(mb25_importexport_subset[['Quantity', 'Value', 'Weight']])  # Define and fit the model

# Calculate Silhouette Score for 3 clusters
mb25_sscore_ag_3cluster = sscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_ag_3cluster_model.labels_)
print("Silhouette Score (3 Clusters - Agglomerative):", mb25_sscore_ag_3cluster)

# Calculate Davies-Bouldin Score for 3 clusters
mb25_dbscore_ag_3cluster = dbscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_ag_3cluster_model.labels_)
print("Davies-Bouldin Score (3 Clusters - Agglomerative):", mb25_dbscore_ag_3cluster)
# Out:
# Silhouette Score (3 Clusters - Agglomerative): 0.1964534526208788
# Davies-Bouldin Score (3 Clusters - Agglomerative): 1.4415796019794802

# %%
# 4 Cluster

# Perform Agglomerative Clustering with 4 clusters
mb25_ag_4cluster_model = AgglomerativeClustering(n_clusters=4).fit(mb25_importexport_subset[['Quantity', 'Value', 'Weight']])  # Define and fit the model

# Calculate Silhouette Score for 4 clusters
mb25_sscore_ag_4cluster = sscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_ag_4cluster_model.labels_)
print("Silhouette Score (4 Clusters - Agglomerative):", mb25_sscore_ag_4cluster)

# Calculate Davies-Bouldin Score for 4 clusters
mb25_dbscore_ag_4cluster = dbscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_ag_4cluster_model.labels_)
print("Davies-Bouldin Score (4 Clusters - Agglomerative):", mb25_dbscore_ag_4cluster)
# Out:
# Silhouette Score (4 Clusters - Agglomerative): 0.21317473272861373
# Davies-Bouldin Score (4 Clusters - Agglomerative): 1.358617938543461

# %%
# 5 Cluster

# Perform Agglomerative Clustering with 5 clusters
mb25_ag_5cluster_model = AgglomerativeClustering(n_clusters=5).fit(mb25_importexport_subset[['Quantity', 'Value', 'Weight']])  # Define and fit the model

# Calculate Silhouette Score for 5 clusters
mb25_sscore_ag_5cluster = sscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_ag_5cluster_model.labels_)
print("Silhouette Score (5 Clusters - Agglomerative):", mb25_sscore_ag_5cluster)

# Calculate Davies-Bouldin Score for 5 clusters
mb25_dbscore_ag_5cluster = dbscore(mb25_importexport_subset[['Quantity', 'Value', 'Weight']], mb25_ag_5cluster_model.labels_)
print("Davies-Bouldin Score (5 Clusters - Agglomerative):", mb25_dbscore_ag_5cluster)
# Out:
# Silhouette Score (5 Clusters - Agglomerative): 0.19955387668577473
# Davies-Bouldin Score (5 Clusters - Agglomerative): 1.251418533288063

# %%
# Making a data frame of 5 cluster

# Get cluster labels from the model
cluster_labels = mb25_ag_5cluster_model.labels_

# Create a DataFrame with cluster labels
cluster_df = pd.DataFrame({'Cluster': cluster_labels}, index=mb25_importexport_subset.index)

# Add cluster labels to the original DataFrame
mb25_importexport_subset['Cluster'] = cluster_labels

# Display the DataFrame with cluster labels
mb25_importexport_subset.head()
# Out:
#    Quantity     Value    Weight  Import_Export_code  Category_code  \
# 0  0.004503  0.840627  0.829563                 0.0            0.0
# 1  0.937456  0.919076  0.069389                 1.0            2.0
# 2  0.246072  0.104915  0.362703                 1.0            1.0
# 3  0.996498  0.047740  0.268721                 0.0            0.0
# 4  0.068748  0.003555  0.359087                 0.0            3.0
#
#    Shipping_Method_code  Payment_Terms_code  Cluster
# 0                   2.0                 3.0        1
# 1                   2.0                 1.0        4
# 2                   2.0                 0.0        2
# 3                   0.0                 0.0        2
# 4                   1.0                 0.0        2

# %%
#Vizualizing 3 Cluster

# Add cluster labels to the DataFrame
mb25_sdf['Cluster'] = cluster_labels

# Choose two features for the scatter plot (e.g., 'Quantity' and 'Value')
x_column = 'Quantity'
y_column = 'Value'

# Create the scatter plot
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.scatter(mb25_sdf[x_column], mb25_sdf[y_column], c=mb25_sdf['Cluster'], cmap='viridis')

# Add labels and title
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Scatter Plot of Clusters')

# Add a colorbar to show cluster mapping
plt.colorbar(label='Cluster')

# Show the plot
plt.show()

# %% [markdown]
# # Supervised Learning

# %%
# Split into test and train dataset
# Assuming 'Cluster' is your target variable (or the cluster assignments)
# and you want an 80/20 split (adjust test_size as needed)

mb25_X = mb25_sdf_clean[['Quantity','Weight']]  # Features (excluding 'Cluster')
mb25_y = mb25_sdf_clean[['Shipping_Method_code']]  # Target variable

mb25_X_train, mb25_X_test, mb25_y_train, mb25_y_test = train_test_split(mb25_X, mb25_y, test_size=0.2, random_state=55025)

# Print the shapes of the resulting datasets
print("X_train shape:", mb25_X_train.shape)
print("X_test shape:", mb25_X_test.shape)
print("y_train shape:", mb25_y_train.shape)
print("y_test shape:", mb25_y_test.shape)
# Out:
# X_train shape: (4000, 2)
# X_test shape: (1001, 2)
# y_train shape: (4000, 1)
# y_test shape: (1001, 1)

# %% [markdown]
# ## Decision Tree

# %%
# Create a Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=55025)

# Fit the model using the training subset
dt_model.fit(mb25_X_train, mb25_y_train)

# Print model details
print("Decision Tree Model Trained Successfully!")
# Out:
# Decision Tree Model Trained Successfully!

# %%
# Record Model Rules
model_rules = export_text(dt_model, feature_names=mb25_X.columns.tolist())
print("Decision Tree Rules:\n", model_rules)

# Record Feature Importance
feature_importance = pd.DataFrame({
    'Feature': mb25_X.columns,
    'Importance': dt_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\nFeature Importance:\n", feature_importance)
# Out:
# Decision Tree Rules:
#  |--- Quantity <= 0.00
# |   |--- Weight <= 0.58
# |   |   |--- Weight <= 0.10
# |   |   |   |--- class: 0.0
# |   |   |--- Weight >  0.10
# |   |   |   |--- class: 1.0
# |   |--- Weight >  0.58
# |   |   |--- class: 0.0
# |--- Quantity >  0.00
# |   |--- Weight <= 0.96
# |   |   |--- Weight <= 0.94
# |   |   |   |--- Weight <= 0.90
# |   |   |   |   |--- Weight <= 0.83
# |   |   |   |   |   |--- Quantity <= 0.02
# |   |   |   |   |   |   |--- Weight <= 0.70
# |   |   |   |   |   |   |   |--- Weight <= 0.61
# |   |   |   |   |   |   |   |   |--- Weight <= 0.49
# |   |   |   |   |   |   |   |   |   |--- Weight <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- Weight <= 0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Weight >  0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Weight >  0.30
# ...

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Generate predictions
mb25_y_pred_dt = dt_model.predict(mb25_X_test)

# Evaluate the model
mb25_accuracy_dt = accuracy_score(mb25_y_test, mb25_y_pred_dt)
print(f"Decision Tree Accuracy: {mb25_accuracy_dt:.2f}")

# Detailed classification report
print("\nClassification Report:")
print(classification_report(mb25_y_test, mb25_y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.33
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.32      0.31       327
#          1.0       0.33      0.33      0.33       326
#          2.0       0.35      0.34      0.35       348
#
#     accuracy                           0.33      1001
#    macro avg       0.33      0.33      0.33      1001
# weighted avg       0.33      0.33      0.33      1001

# %%
# Confusion matrix

mb25_cm = confusion_matrix(mb25_y_test, mb25_y_pred_dt)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(mb25_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=dt_model.classes_, yticklabels=dt_model.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
# Initialize the Logistic Regression model
mb25_logreg_classifier = LogisticRegression(random_state=55025)

# Train the model
mb25_logreg_classifier.fit(mb25_X_train, mb25_y_train)

# Make predictions on the test set
y_pred_logreg = mb25_logreg_classifier.predict(mb25_X_test)

# Evaluate the model
mb25_accuracy_logreg = accuracy_score(mb25_y_test, y_pred_logreg)
print(f"Logistic Regression Accuracy: {mb25_accuracy_logreg}")
print(classification_report(mb25_y_test, y_pred_logreg))
# Out:
# Logistic Regression Accuracy: 0.34065934065934067
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.31      0.32       327
#          1.0       0.32      0.12      0.17       326
#          2.0       0.35      0.58      0.44       348
#
#     accuracy                           0.34      1001
#    macro avg       0.33      0.34      0.31      1001
# weighted avg       0.33      0.34      0.31      1001
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Confusion Matrix for Logistic Regression
cm_logreg = confusion_matrix(mb25_y_test, y_pred_logreg)

# Plot the confusion matrix for Logistic Regression
plt.figure(figsize=(8, 6))
sns.heatmap(cm_logreg, annot=True, fmt='d', cmap='Greens',  # Different colormap
            xticklabels=mb25_logreg_classifier.classes_, yticklabels=mb25_logreg_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %%
# Comparision of Lr and DT

print(f"Decision Tree Accuracy: {mb25_accuracy_dt}")
print(f"Logistic Regression Accuracy: {mb25_accuracy_logreg}")

if mb25_accuracy_dt > mb25_accuracy_logreg:
    print("Decision Tree model performs better.")
elif mb25_accuracy_logreg > mb25_accuracy_dt:
    print("Logistic Regression model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.32967032967032966
# Logistic Regression Accuracy: 0.34065934065934067
# Logistic Regression model performs better.

# %% [markdown]
# ## Ensembled learning

# %% [markdown]
# ### Random Forest

# %%
# Initialize the Random Forest Classifier
mb25_rf_classifier = RandomForestClassifier(random_state=55025)

# Train the model
mb25_rf_classifier.fit(mb25_X_train, mb25_y_train)

# Make predictions on the test set
y_pred_rf = mb25_rf_classifier.predict(mb25_X_test)

# Evaluate the model
mb25_accuracy_rf = accuracy_score(mb25_y_test, y_pred_rf)
print(f"Random Forest Accuracy: {mb25_accuracy_rf}")
print(classification_report(mb25_y_test, y_pred_rf))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest Accuracy: 0.3356643356643357
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.31      0.32       327
#          1.0       0.34      0.32      0.33       326
#          2.0       0.35      0.37      0.36       348
#
#     accuracy                           0.34      1001
#    macro avg       0.34      0.33      0.33      1001
# weighted avg       0.34      0.34      0.34      1001

# %%
# Confusion Matrix for Random Forest
cm_rf = confusion_matrix(mb25_y_test, y_pred_rf)

# Plot the confusion matrix for Random Forest
plt.figure(figsize=(8, 6))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Oranges',  # Different colormap
            xticklabels=mb25_rf_classifier.classes_, yticklabels=mb25_rf_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %%
# Compare Random Forest and Decision Tree

print(f"\nDecision Tree Accuracy: {mb25_accuracy_dt}")
print(f"Random Forest Accuracy: {mb25_accuracy_rf}")

if mb25_accuracy_rf > mb25_accuracy_dt:
    print("Random Forest performs better than Decision Tree.")
elif mb25_accuracy_dt > mb25_accuracy_rf:
    print("Decision Tree performs better than Random Forest.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.32967032967032966
# Random Forest Accuracy: 0.3356643356643357
# Random Forest performs better than Decision Tree.
